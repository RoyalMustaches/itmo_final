# %%
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib

try:
    from IPython import get_ipython
except Exception:
    get_ipython = None

_ip = get_ipython() if get_ipython else None
if _ip is not None:
    try:
        _ip.run_line_magic("matplotlib", "inline")
    except Exception:
        pass
else:
    matplotlib.use("Agg")

import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager, FontProperties

plt.ioff()


try:
    from IPython.display import display
except Exception:
    def display(obj):
        print(obj)

df_path = "/Users/royalmustaches/Documents/Programming/Dano/DANO_ITMO_2026/Datasets/new_data.csv"
df = pd.read_csv(df_path)

PALETTE = ["#5e17eb", "#ff6b6b", "#00c49a"]
FONT_CANDIDATES = [
    "/Users/royalmustaches/Documents/Programming/Dano/DANO_ITMO_2026/HSE_FONTS_FOR_GRAPHS_copy/HSESlab-Regular.ttf",
    "/Users/royalmustaches/Documents/Programming/Dano/DANO_NES_2026/HSE_FONTS_FOR_GRAPHS/HSESlab-Regular.ttf",
    "/Users/royalmustaches/Documents/Programming/Dano/Practice/Organization/Fonts_for_projects/HSESlab-Regular.ttf",
]

FONT_NAME = "DejaVu Sans"
for font_path in FONT_CANDIDATES:
    if os.path.exists(font_path):
        fontManager.addfont(font_path)
        FONT_NAME = FontProperties(fname=font_path).get_name()
        break

sns.set_theme(style="whitegrid", font=FONT_NAME, context="notebook", palette=PALETTE)
plt.rcParams["axes.grid"] = True
plt.rcParams["grid.alpha"] = 0.3
plt.rcParams["grid.linestyle"] = "--"

plt.rcParams["figure.dpi"] = 160
plt.rcParams["savefig.dpi"] = 300
plt.rcParams["axes.titlesize"] = 14
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["xtick.labelsize"] = 11
plt.rcParams["ytick.labelsize"] = 11
plt.rcParams["legend.fontsize"] = 11
plt.rcParams["lines.linewidth"] = 2.5

PRIMARY = "#5e17eb"
SECONDARY = "#ff6b6b"
ACCENT = "#00c49a"

# %%
import pandas as pd
import numpy as np

import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib.pyplot as plt
import seaborn as sns

# =========================
# 1. Подготовка данных
# =========================

for col in ['gmv_with_markup']:
  
    s = pd.to_numeric(df[col], errors='coerce')
    valid = s.dropna()

    if valid.empty:
        print(f"Колонка {col} не содержит числовых значений, шаг пропущен.")
        continue

    q1 = valid.quantile(0.25)
    q3 = valid.quantile(0.75)
    iqr = q3 - q1

    if pd.isna(iqr) or iqr == 0:
        print(f"Для {col} IQR = 0/NaN, выбросы не удалялись. Строк: {len(df)}")
        continue

    upper_whisker = q3 + 1.5 * iqr
    keep_mask = s.isna() | (s <= upper_whisker)

    before = len(df)
    df = df[keep_mask].copy()
    print(f"После очистки {col}: {len(df)} строк (удалено {before - len(df)})")

df_model = df.copy()

df_model.columns = (
    df_model.columns
    .str.replace('\ufeff', '', regex=False)
    .str.strip()
)

df_model = df_model[df_model['gmv_with_markup'] > 0].copy()

df_model = df_model.dropna(
    subset=[
        'gmv_with_markup',
        'markup',
        'cb_percent'
    ]
).copy()

df_model = df_model[df_model['markup'].isin([0, 1, 5, 9])].copy()
df_model['markup'] = df_model['markup'].astype(int)

# =========================
# 2. Флаги наценки
# =========================
# Базовая группа: markup = 0
# Сами флаги отдельно в модель не включаем

df_model['markup_1'] = (df_model['markup'] == 1).astype(int)
df_model['markup_5'] = (df_model['markup'] == 5).astype(int)
df_model['markup_9'] = (df_model['markup'] == 9).astype(int)

# =========================
# 3. cb_percent, квадрат и взаимодействия
# =========================

df_model['cb_percent_sq'] = df_model['cb_percent'] ** 2

df_model['cb_x_markup_1'] = df_model['cb_percent'] * df_model['markup_1']
df_model['cb_x_markup_5'] = df_model['cb_percent'] * df_model['markup_5']
df_model['cb_x_markup_9'] = df_model['cb_percent'] * df_model['markup_9']

# =========================
# 4. Линейная регрессия
# =========================

formula = """
gmv_with_markup ~ cb_percent
                + cb_percent_sq
                + cb_x_markup_1
                + cb_x_markup_5
                + cb_x_markup_9
"""

if 'client_id' in df_model.columns:
    model_gmv_cb_sq = smf.ols(
        formula=formula,
        data=df_model
    ).fit(
        cov_type='cluster',
        cov_kwds={'groups': df_model['client_id']}
    )
else:
    model_gmv_cb_sq = smf.ols(
        formula=formula,
        data=df_model
    ).fit(cov_type='HC3')

print(model_gmv_cb_sq.summary())

# =========================
# 5. Таблица коэффициентов
# =========================

coef_table = model_gmv_cb_sq.summary2().tables[1].reset_index()
coef_table = coef_table.rename(columns={
    'index': 'term',
    'Coef.': 'coef',
    'Std.Err.': 'std_err',
    '[0.025': 'ci_low',
    '0.975]': 'ci_high',
    'P>|z|': 'p_value'
})

display(coef_table)

# =========================
# 6. Совместные тесты
# =========================

print('Совместный тест взаимодействий cb_percent × markup:')
print(
    model_gmv_cb_sq.wald_test(
        'cb_x_markup_1 = 0, cb_x_markup_5 = 0, cb_x_markup_9 = 0'
    )
)

print('Тест квадратичного эффекта cb_percent:')
print(
    model_gmv_cb_sq.wald_test(
        'cb_percent_sq = 0'
    )
)

# =========================
# 7. Матрица корреляций предикторов
# =========================

predictors = [
    'cb_percent',
    'cb_percent_sq',
    'cb_x_markup_1',
    'cb_x_markup_5',
    'cb_x_markup_9'
]

X = df_model[predictors].dropna().copy()

corr_matrix = X.corr()

display(corr_matrix)

plt.figure(figsize=(9, 7))

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    square=True,
    linewidths=0.7,
    annot_kws={"size": 10}
)

plt.title('Матрица корреляций предикторов модели')
plt.tight_layout()
plt.show()

# =========================
# 8. VIF
# =========================

X_vif = sm.add_constant(X)

vif_table = pd.DataFrame({
    'variable': X_vif.columns,
    'VIF': [
        variance_inflation_factor(X_vif.values, i)
        for i in range(X_vif.shape[1])
    ]
})

vif_table = vif_table[vif_table['variable'] != 'const'].copy()
vif_table = vif_table.sort_values('VIF', ascending=False)

display(vif_table)

# =========================
# 9. Предсказания модели
# =========================

cb_min = df_model['cb_percent'].quantile(0.01)
cb_max = df_model['cb_percent'].quantile(0.99)

cb_grid = np.linspace(cb_min, cb_max, 100)

pred_grid = pd.DataFrame([
    {
        'cb_percent': cb,
        'markup': markup
    }
    for cb in cb_grid
    for markup in [0, 1, 5, 9]
])

pred_grid['cb_percent_sq'] = pred_grid['cb_percent'] ** 2

pred_grid['markup_1'] = (pred_grid['markup'] == 1).astype(int)
pred_grid['markup_5'] = (pred_grid['markup'] == 5).astype(int)
pred_grid['markup_9'] = (pred_grid['markup'] == 9).astype(int)

pred_grid['cb_x_markup_1'] = pred_grid['cb_percent'] * pred_grid['markup_1']
pred_grid['cb_x_markup_5'] = pred_grid['cb_percent'] * pred_grid['markup_5']
pred_grid['cb_x_markup_9'] = pred_grid['cb_percent'] * pred_grid['markup_9']

pred = model_gmv_cb_sq.get_prediction(pred_grid).summary_frame(alpha=0.05)

pred_grid['predicted_gmv'] = pred['mean']
pred_grid['ci_low'] = pred['mean_ci_lower']
pred_grid['ci_high'] = pred['mean_ci_upper']

display(pred_grid)

# =========================
# 10. График предсказаний модели
# =========================

plt.figure(figsize=(12, 8))

pred_palette = {
    0: '#1b9e77',
    1: '#d95f02',
    5: '#7570b3',
    9: '#e7298a'
}

sns.lineplot(
    data=pred_grid,
    x='cb_percent',
    y='predicted_gmv',
    hue='markup',
    hue_order=[0, 1, 5, 9],
    palette=pred_palette,
    linewidth=2.8
)

for markup_value in [0, 1, 5, 9]:
    temp = pred_grid[pred_grid['markup'] == markup_value]

    plt.fill_between(
        temp['cb_percent'],
        temp['ci_low'],
        temp['ci_high'],
        color=pred_palette[markup_value],
        alpha=0.20
    )

plt.title('Предсказанный GMV по кэшбэку, квадрату кэшбэка и наценке')
plt.xlabel('Кэшбэк, %')
plt.ylabel('Предсказанный gmv_with_markup')
plt.legend(title='Наценка, %')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# =========================
# 11. Описательный bootstrap-график средних GMV
# =========================

plot_data = df_model[
    [
        'markup',
        'cb_percent',
        'gmv_with_markup'
    ]
].dropna().copy()

cb_markup_avg = (
    plot_data
    .groupby(['markup', 'cb_percent'], as_index=False)
    .agg(
        gmv_mean=('gmv_with_markup', 'mean'),
        n_orders=('gmv_with_markup', 'size')
    )
)

display(cb_markup_avg)

def bootstrap_poly_fit(x, y, x_fit, degree=2, n_bootstraps=1000, confidence=0.95):
    x = np.asarray(x)
    y = np.asarray(y)

    n = len(x)
    bootstrap_fits = np.zeros((n_bootstraps, len(x_fit)))

    for i in range(n_bootstraps):
        indices = np.random.choice(n, n, replace=True)

        x_resample = x[indices]
        y_resample = y[indices]

        if len(np.unique(x_resample)) <= degree:
            bootstrap_fits[i, :] = np.nan
            continue

        coefficients_resample = np.polyfit(x_resample, y_resample, degree)
        polynomial_resample = np.poly1d(coefficients_resample)

        bootstrap_fits[i, :] = polynomial_resample(x_fit)

    lower_percentile = (1 - confidence) / 2 * 100
    upper_percentile = (1 + confidence) / 2 * 100

    lower_bound = np.nanpercentile(bootstrap_fits, lower_percentile, axis=0)
    upper_bound = np.nanpercentile(bootstrap_fits, upper_percentile, axis=0)

    return lower_bound, upper_bound

plt.figure(figsize=(12, 8))

palette = {
    0: 'purple',
    1: 'blue',
    5: 'green',
    9: 'red'
}

degree = 2

for markup_value in [0, 1, 5, 9]:
    temp = cb_markup_avg[cb_markup_avg['markup'] == markup_value].copy()

    if temp['cb_percent'].nunique() <= degree:
        print(f"Для markup={markup_value}% слишком мало уникальных значений cb_percent")
        continue

    x_data = temp['cb_percent'].values
    y_data = temp['gmv_mean'].values

    plt.scatter(
        x_data,
        y_data,
        color=palette[markup_value],
        alpha=0.85,
        edgecolor="white",
        linewidth=0.5,
        label=f'Наценка {markup_value}%: средний GMV'
    )

    coefficients = np.polyfit(x_data, y_data, degree)
    polynomial = np.poly1d(coefficients)

    x_fit = np.linspace(x_data.min(), x_data.max(), 100)
    y_fit = polynomial(x_fit)

    plt.plot(
        x_fit,
        y_fit,
        color=palette[markup_value],
        linewidth=2.8
    )

    lower_bound, upper_bound = bootstrap_poly_fit(
        x=x_data,
        y=y_data,
        x_fit=x_fit,
        degree=degree,
        n_bootstraps=1000,
        confidence=0.95
    )

    plt.fill_between(
        x_fit,
        lower_bound,
        upper_bound,
        color=palette[markup_value],
        alpha=0.15
    )

plt.title("Средний GMV по кэшбэку и уровню наценки")
plt.xlabel("Кэшбэк, %")
plt.ylabel("Средний gmv_with_markup")
plt.legend(title='Наценка')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# После очистки gmv_with_markup: 90480 строк (удалено 5249)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        gmv_with_markup   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     9.096
# Date:                Sat, 25 Apr 2026   Prob (F-statistic):           1.17e-08
# Time:                        22:51:59   Log-Likelihood:            -7.5608e+05
# No. Observations:               90480   AIC:                         1.512e+06
# Df Residuals:                   90474   BIC:                         1.512e+06
# Df Model:                           5
# Covariance Type:              cluster
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1590.4137      9.964    159.623      0.000    1570.885    1609.942
# cb_percent        4.5116      2.128      2.120      0.034       0.341       8.682
# cb_percent_sq    -0.3319      0.101     -3.292      0.001      -0.530      -0.134
# cb_x_markup_1     6.6380      1.177      5.641      0.000       4.332       8.944
# cb_x_markup_5     2.9861      1.174      2.544      0.011       0.686       5.286
# cb_x_markup_9     2.6493      1.185      2.236      0.025       0.327       4.971
# ==============================================================================
# Omnibus:                     9792.912   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13320.725
# Skew:                           0.932   Prob(JB):                         0.00
# Kurtosis:                       3.236   Cond. No.                         350.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#             term         coef   std_err           z       p_value  \
# 0      Intercept  1590.413720  9.963587  159.622598  0.000000e+00
# 1     cb_percent     4.511561  2.127774    2.120319  3.397913e-02
# 2  cb_percent_sq    -0.331911  0.100836   -3.291578  9.962707e-04
# 3  cb_x_markup_1     6.638001  1.176718    5.641116  1.689516e-08
# 4  cb_x_markup_5     2.986074  1.173584    2.544406  1.094639e-02
# 5  cb_x_markup_9     2.649341  1.184698    2.236301  2.533204e-02
#
#         ci_low      ci_high
# 0  1570.885448  1609.941993
# 1     0.341200     8.681921
# 2    -0.529547    -0.134275
# 3     4.331677     8.944325
# 4     0.685891     5.286256
# 5     0.327376     4.971305
# Совместный тест взаимодействий cb_percent × markup:
# <Wald test (chi2): statistic=[[31.95301499]], p-value=5.354159937078869e-07, df_denom=3>
# Тест квадратичного эффекта cb_percent:
# <Wald test (chi2): statistic=[[10.83448419]], p-value=0.00099627067573866, df_denom=1>
#                cb_percent  cb_percent_sq  cb_x_markup_1  cb_x_markup_5  \
# cb_percent       1.000000       0.930636       0.300102       0.302432
# cb_percent_sq    0.930636       1.000000       0.277320       0.283872
# cb_x_markup_1    0.300102       0.277320       1.000000      -0.198193
# cb_x_markup_5    0.302432       0.283872      -0.198193       1.000000
# cb_x_markup_9    0.291802       0.270252      -0.195393      -0.191447
#
#                cb_x_markup_9
# cb_percent          0.291802
# cb_percent_sq       0.270252
# cb_x_markup_1      -0.195393
# cb_x_markup_5      -0.191447
# cb_x_markup_9       1.000000
#         variable       VIF
# 1     cb_percent  8.254546
# 2  cb_percent_sq  7.467854
# 3  cb_x_markup_1  1.535826
# 4  cb_x_markup_5  1.534675
# 5  cb_x_markup_9  1.515969
#      cb_percent  markup  cb_percent_sq  markup_1  markup_5  markup_9  \
# 0      0.000000       0       0.000000         0         0         0
# 1      0.000000       1       0.000000         1         0         0
# 2      0.000000       5       0.000000         0         1         0
# 3      0.000000       9       0.000000         0         0         1
# 4      0.252525       0       0.063769         0         0         0
# ..          ...     ...            ...       ...       ...       ...
# 395   24.747475       9     612.437506         0         0         1
# 396   25.000000       0     625.000000         0         0         0
# 397   25.000000       1     625.000000         1         0         0
# 398   25.000000       5     625.000000         0         1         0
# 399   25.000000       9     625.000000         0         0         1
#
#      cb_x_markup_1  cb_x_markup_5  cb_x_markup_9  predicted_gmv       ci_low  \
# 0              0.0            0.0       0.000000    1590.413720  1570.885448
# 1              0.0            0.0       0.000000    1590.413720  1570.885448
# 2              0.0            0.0       0.000000    1590.413720  1570.885448
# 3              0.0            0.0       0.000000    1590.413720  1570.885448
# 4              0.0            0.0       0.000000    1591.531838  1572.701005
# ..             ...            ...            ...            ...          ...
# 395            0.0            0.0      24.747475    1564.353088  1504.817244
# 396            0.0            0.0       0.000000    1495.758249  1437.782088
# 397           25.0            0.0       0.000000    1661.708274  1601.498007
# 398            0.0           25.0       0.000000    1570.410092  1510.388797
# 399            0.0            0.0      25.000000    1561.991765  1501.039965
#
#          ci_high
# 0    1609.941993
# 1    1609.941993
# 2    1609.941993
# 3    1609.941993
# 4    1610.362670
# ..           ...
# 395  1623.888933
# 396  1553.734411
# 397  1721.918541
# 398  1630.431386
# 399  1622.943564
#
# [400 rows x 12 columns]
#     markup  cb_percent     gmv_mean  n_orders
# 0        0           0  1531.360932      5838
# 1        0           5  1633.686112      1327
# 2        0           7  1601.742638      4874
# 3        0          10  1550.171609      2561
# 4        0          12  1550.932250      5466
# 5        0          15  1618.757443      2495
# 6        0          17  1637.525558      2706
# 7        0          18  1614.801071       112
# 8        0          20  1521.799451       164
# 9        0          23  1405.707073       246
# 10       0          25  1563.403270       315
# 11       1           0  1662.636857      4317
# 12       1           5  1617.504066      1205
# 13       1           7  1672.878000      4201
# 14       1          10  1632.408711      2305
# 15       1          12  1647.276878      4631
# 16       1          15  1711.510069      2018
# 17       1          17  1719.014951      2343
# 18       1          18  1608.235766       111
# 19       1          20  1553.425300       100
# 20       1          23  1510.749621       211
# 21       1          25  1800.861822       258
# 22       5           0  1583.621333      4695
# 23       5           5  1716.767707      1147
# 24       5           7  1668.569885      4011
# 25       5          10  1623.169481      2101
# 26       5          12  1633.563147      4484
# 27       5          15  1627.391900      2005
# 28       5          17  1623.997562      2371
# 29       5          18  1405.059063        96
# 30       5          20  1589.602957       115
# 31       5          23  1423.397277       213
# 32       5          25  1502.678855       262
# 33       9           0  1579.400628      4776
# 34       9           5  1707.137779      1130
# 35       9           7  1642.187155      3955
# 36       9          10  1578.846733      2124
# 37       9          12  1619.646746      4394
# 38       9          15  1595.766178      1863
# 39       9          17  1664.490508      2303
# 40       9          18  1726.655730        89
# 41       9          20  1516.665083       120
# 42       9          23  1494.520179       168
# 43       9          25  1523.137362       254

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# =========================
# 1. Подготовка переменных
# =========================

df_corr = df_model.copy()

df_corr.columns = (
    df_corr.columns
    .str.replace('\ufeff', '', regex=False)
    .str.strip()
)

# Если переменные еще не созданы, создаем их
if 'cb_percent_sq' not in df_corr.columns:
    df_corr['cb_percent_sq'] = df_corr['cb_percent'] ** 2

if 'cb_x_markup_1' not in df_corr.columns:
    df_corr['cb_x_markup_1'] = df_corr['cb_percent'] * (df_corr['markup'].astype(str) == '1').astype(int)

if 'cb_x_markup_5' not in df_corr.columns:
    df_corr['cb_x_markup_5'] = df_corr['cb_percent'] * (df_corr['markup'].astype(str) == '5').astype(int)

if 'cb_x_markup_9' not in df_corr.columns:
    df_corr['cb_x_markup_9'] = df_corr['cb_percent'] * (df_corr['markup'].astype(str) == '9').astype(int)

columns_to_p_value_corr = [
    'cb_percent',
    'cb_percent_sq',
    'cb_x_markup_1',
    'cb_x_markup_5',
    'cb_x_markup_9'
]

df_corr = df_corr[columns_to_p_value_corr].apply(pd.to_numeric, errors='coerce')

# =========================
# 2. Функция для p-value
# =========================

def pearsonr_pval(x, y):
    valid = pd.concat([pd.Series(x), pd.Series(y)], axis=1).dropna()

    if valid.shape[0] < 3:
        return np.nan

    if valid.iloc[:, 0].nunique() <= 1 or valid.iloc[:, 1].nunique() <= 1:
        return np.nan

    return st.pearsonr(valid.iloc[:, 0], valid.iloc[:, 1])[1]

# =========================
# 3. Матрица p-value
# =========================

pval_matrix = df_corr.corr(method=pearsonr_pval)

# Для диагонали p-value не имеет смысла
pval_matrix = pval_matrix.where(~np.eye(len(pval_matrix), dtype=bool), np.nan)

# Формат подписей в научной записи
annot_matrix = pval_matrix.map(lambda x: f'{x:.1e}' if pd.notna(x) else '')

# =========================
# 4. Heatmap
# =========================

plt.figure(figsize=(9, 6))

sns.heatmap(
    pval_matrix,
    linewidths=0.5,
    cmap='PRGn_r',
    cbar_kws={'shrink': 0.8, 'label': 'p-value'},
    annot=annot_matrix,
    fmt=''
)

plt.title('Матрица p-value Pearson-корреляций между предикторами')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# =========================
# Проверка устойчивости при добавлении контролей
# =========================

base_formula = """
gmv_with_markup ~ cb_percent
                + cb_percent_sq
                + cb_x_markup_1
                + cb_x_markup_5
                + cb_x_markup_9
"""

candidate_controls = [
    'gender_cd',
    'age_group',
    'income_group',
    'lifestyle___super_cnt',
    'lifestyle___super_sum'
]

available_controls = [
    col for col in candidate_controls
    if col in df_model.columns
]

formulas = {
    'base': base_formula,
    'with_gender_age': base_formula + ' + C(gender_cd) + C(age_group)'
        if {'gender_cd', 'age_group'}.issubset(df_model.columns)
        else base_formula,
    'with_income': base_formula + ' + C(income_group)'
        if 'income_group' in df_model.columns
        else base_formula,
    'with_history': base_formula + ' + lifestyle___super_cnt + lifestyle___super_sum'
        if {'lifestyle___super_cnt', 'lifestyle___super_sum'}.issubset(df_model.columns)
        else base_formula,
    'full_controls': base_formula + ''.join(
        [
            ' + C(gender_cd)' if 'gender_cd' in df_model.columns else '',
            ' + C(age_group)' if 'age_group' in df_model.columns else '',
            ' + C(income_group)' if 'income_group' in df_model.columns else '',
            ' + lifestyle___super_cnt' if 'lifestyle___super_cnt' in df_model.columns else '',
            ' + lifestyle___super_sum' if 'lifestyle___super_sum' in df_model.columns else ''
        ]
    )
}

control_results = []

for model_name, f in formulas.items():
    temp = df_model.copy()

    needed_cols = [
        'gmv_with_markup',
        'cb_percent',
        'cb_percent_sq',
        'cb_x_markup_1',
        'cb_x_markup_5',
        'cb_x_markup_9'
    ]

    temp = temp.dropna(subset=[col for col in needed_cols if col in temp.columns]).copy()

    base_fit = smf.ols(formula=f, data=temp).fit()

    if 'client_id' in temp.columns and temp['client_id'].nunique() > 1:
        used_idx = base_fit.model.data.row_labels
        groups = temp.loc[used_idx, 'client_id']
        model = base_fit.get_robustcov_results(
            cov_type='cluster',
            groups=groups
        )
    else:
        model = base_fit.get_robustcov_results(cov_type='HC3')

    param_names = model.model.exog_names
    params = pd.Series(model.params, index=param_names)
    pvalues = pd.Series(model.pvalues, index=param_names)

    for term in [
        'cb_percent',
        'cb_percent_sq',
        'cb_x_markup_1',
        'cb_x_markup_5',
        'cb_x_markup_9'
    ]:
        if term in params.index:
            control_results.append({
                'model': model_name,
                'n_obs': int(model.nobs),
                'term': term,
                'coef': params[term],
                'p_value': pvalues[term],
                'r_squared': model.rsquared,
                'aic': model.aic
            })

control_results = pd.DataFrame(control_results)

display(control_results)
# Out:
#               model  n_obs           term      coef       p_value  r_squared  \
# 0              base  90480     cb_percent  4.511561  3.398443e-02   0.000924
# 1              base  90480  cb_percent_sq -0.331911  9.970159e-04   0.000924
# 2              base  90480  cb_x_markup_1  6.638001  1.699351e-08   0.000924
# 3              base  90480  cb_x_markup_5  2.986074  1.094961e-02   0.000924
# 4              base  90480  cb_x_markup_9  2.649341  2.533679e-02   0.000924
# 5   with_gender_age  90306     cb_percent  2.095473  3.164867e-01   0.027900
# 6   with_gender_age  90306  cb_percent_sq -0.199279  4.545272e-02   0.027900
# 7   with_gender_age  90306  cb_x_markup_1  6.412544  2.965626e-08   0.027900
# 8   with_gender_age  90306  cb_x_markup_5  2.775073  1.713692e-02   0.027900
# 9   with_gender_age  90306  cb_x_markup_9  2.882119  1.297275e-02   0.027900
# 10      with_income  90480     cb_percent  5.690972  7.217388e-03   0.012664
# 11      with_income  90480  cb_percent_sq -0.358619  3.559189e-04   0.012664
# 12      with_income  90480  cb_x_markup_1  6.705148  9.417089e-09   0.012664
# 13      with_income  90480  cb_x_markup_5  3.010375  9.973547e-03   0.012664
# 14      with_income  90480  cb_x_markup_9  2.509308  3.312139e-02   0.012664
# 15     with_history  90480     cb_percent  5.590345  3.567659e-03   0.162152
# 16     with_history  90480  cb_percent_sq -0.171065  7.345755e-02   0.162152
# 17     with_history  90480  cb_x_markup_1  5.622074  8.321345e-08   0.162152
# 18     with_history  90480  cb_x_markup_5  1.972763  5.819593e-02   0.162152
# 19     with_history  90480  cb_x_markup_9  0.776430  4.626978e-01   0.162152
# 20    full_controls  90306     cb_percent  4.154603  2.895513e-02   0.177627
# 21    full_controls  90306  cb_percent_sq -0.114637  2.252857e-01   0.177627
# 22    full_controls  90306  cb_x_markup_1  5.505947  1.080907e-07   0.177627
# 23    full_controls  90306  cb_x_markup_5  1.887919  6.767680e-02   0.177627
# 24    full_controls  90306  cb_x_markup_9  0.962955  3.555915e-01   0.177627
#
#              aic
# 0   1.512182e+06
# 1   1.512182e+06
# 2   1.512182e+06
# 3   1.512182e+06
# 4   1.512182e+06
# 5   1.506809e+06
# 6   1.506809e+06
# 7   1.506809e+06
# 8   1.506809e+06
# 9   1.506809e+06
# 10  1.511124e+06
# 11  1.511124e+06
# 12  1.511124e+06
# 13  1.511124e+06
# 14  1.511124e+06
# 15  1.496262e+06
# 16  1.496262e+06
# 17  1.496262e+06
# 18  1.496262e+06
# 19  1.496262e+06
# 20  1.491720e+06
# 21  1.491720e+06
# 22  1.491720e+06
# 23  1.491720e+06
# 24  1.491720e+06
